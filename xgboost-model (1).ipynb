# %%
import os
import numpy as np
import librosa
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
import gc
from concurrent.futures import ProcessPoolExecutor

# Function to process a single audio file (unchanged)
def process_audio_file(file_info, max_length=100):
    file_path, label = file_info
    try:
        audio, _ = librosa.load(file_path, sr=4000)
        stft = librosa.stft(audio, n_fft=256, hop_length=128)
        spectrogram = np.abs(stft)

        if spectrogram.shape[1] < max_length:
            spectrogram = np.pad(spectrogram, ((0, 0), (0, max_length - spectrogram.shape[1])), mode='constant')
        else:
            spectrogram = spectrogram[:, :max_length]

        return spectrogram.astype(np.float32), label
    except Exception as e:
        print(f"Error with file: {file_path} -> {str(e)}")
        return None, None

# Generator for audio files and labels (unchanged)
def audio_file_generator(fake_root_dirs, real_root_dir):
    for fake_root_dir in fake_root_dirs:
        for file in os.listdir(fake_root_dir):
            file_path = os.path.join(fake_root_dir, file)
            yield file_path, 1
    for file in os.listdir(real_root_dir):
        file_path = os.path.join(real_root_dir, file)
        yield file_path, 0

# Feature extraction for spectrogram (unchanged)
def extract_spectrogram_features(fake_root_dirs, real_root_dir, max_length=250, max_workers=4):
    features = []
    labels = []

    total_files = sum(len(os.listdir(d)) for d in fake_root_dirs) + len(os.listdir(real_root_dir))

    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        results = list(tqdm(executor.map(process_audio_file, 
                                         audio_file_generator(fake_root_dirs, real_root_dir)), 
                            total=total_files, desc='Processing audio files'))

    for spectrogram, label in results:
        if spectrogram is not None:
            features.append(spectrogram)
            labels.append(label)

    del results
    gc.collect()

    return np.array(features), np.array(labels)

# Specify fake and real directories (unchanged)
fake_root_dirs = [
    '/kaggle/input/wavefake-test/generated_audio/ljspeech_melgan',
    '/kaggle/input/wavefake-test/generated_audio/ljspeech_melgan_large',
    '/kaggle/input/wavefake-test/generated_audio/ljspeech_waveglow'
]
real_root_dir = '/kaggle/input/the-lj-speech-dataset/LJSpeech-1.1/wavs'

# Extract features for spectrogram (unchanged)
x_spectrogram, y_spectrogram = extract_spectrogram_features(fake_root_dirs, real_root_dir)

# Flatten the 2D spectrogram arrays for XGBoost
x_spectrogram = x_spectrogram.reshape(x_spectrogram.shape[0], -1)

# Split into training and testing
xtrain_s, xtest_s, ytrain_s, ytest_s = train_test_split(x_spectrogram, y_spectrogram, test_size=0.3, random_state=42)

# Train and evaluate Spectrogram model with regularization and early stopping
model_spectrogram = XGBClassifier(
    n_estimators=500,          # Increase number of trees
    max_depth=6,               # Max depth of trees
    learning_rate=0.01,        # Reduce learning rate to make the model learn slower
    subsample=0.8,             # Randomly sample 80% of the data to avoid overfitting
    colsample_bytree=0.8,      # Randomly sample 80% of features to avoid overfitting
    reg_alpha=0.01,            # L1 regularization (add sparsity)
    reg_lambda=0.1,            # L2 regularization
    early_stopping_rounds=50,  # Stop if no improvement after 50 rounds
    random_state=42
)

# Train the model and use early stopping based on validation data
model_spectrogram.fit(
    xtrain_s, ytrain_s,
    eval_set=[(xtest_s, ytest_s)],
    eval_metric="logloss",
    verbose=True
)

# Evaluate the model
ypred_s = model_spectrogram.predict(xtest_s)
accuracy_s = accuracy_score(ytest_s, ypred_s)
print(f"Spectrogram Model Accuracy (with regularization): {accuracy_s:.4f}")
print(classification_report(ytest_s, ypred_s))
# Out:
# Processing audio files: 100%|██████████| 52400/52400 [04:35<00:00, 189.91it/s]
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.55742
# [1]	validation_0-logloss:0.55338
# [2]	validation_0-logloss:0.54929
# [3]	validation_0-logloss:0.54526
# [4]	validation_0-logloss:0.54126
# [5]	validation_0-logloss:0.53743
# [6]	validation_0-logloss:0.53366
# [7]	validation_0-logloss:0.52993
# [8]	validation_0-logloss:0.52617
# [9]	validation_0-logloss:0.52253
# [10]	validation_0-logloss:0.51891
# [11]	validation_0-logloss:0.51540
# [12]	validation_0-logloss:0.51190
# [13]	validation_0-logloss:0.50855
# [14]	validation_0-logloss:0.50519
# [15]	validation_0-logloss:0.50185
# [16]	validation_0-logloss:0.49849
# [17]	validation_0-logloss:0.49526
# [18]	validation_0-logloss:0.49209
# [19]	validation_0-logloss:0.48900
# [20]	validation_0-logloss:0.48593
# [21]	validation_0-logloss:0.48293
# [22]	validation_0-logloss:0.47979
# [23]	validation_0-logloss:0.47686
# [24]	validation_0-logloss:0.47389
# [25]	validation_0-logloss:0.47098
# [26]	validation_0-logloss:0.46811
# [27]	validation_0-logloss:0.46537
# [28]	validation_0-logloss:0.46260
# [29]	validation_0-logloss:0.45997
# [30]	validation_0-logloss:0.45727
# [31]	validation_0-logloss:0.45456
# [32]	validation_0-logloss:0.45183
# [33]	validation_0-logloss:0.44919
# [34]	validation_0-logloss:0.44661
# [35]	validation_0-logloss:0.44400
# [36]	validation_0-logloss:0.44145
# [37]	validation_0-logloss:0.43888
# [38]	validation_0-logloss:0.43638
# [39]	validation_0-logloss:0.43393
# [40]	validation_0-logloss:0.43141
# [41]	validation_0-logloss:0.42896
# [42]	validation_0-logloss:0.42652
# [43]	validation_0-logloss:0.42405
# [44]	validation_0-logloss:0.42174
# [45]	validation_0-logloss:0.41941
# [46]	validation_0-logloss:0.41712
# [47]	validation_0-logloss:0.41479
# [48]	validation_0-logloss:0.41249
# [49]	validation_0-logloss:0.41024
# [50]	validation_0-logloss:0.40808
# [51]	validation_0-logloss:0.40588
# [52]	validation_0-logloss:0.40375
# [53]	validation_0-logloss:0.40163
# [54]	validation_0-logloss:0.39952
# [55]	validation_0-logloss:0.39740
# [56]	validation_0-logloss:0.39526
# [57]	validation_0-logloss:0.39327
# [58]	validation_0-logloss:0.39120
# [59]	validation_0-logloss:0.38916
# [60]	validation_0-logloss:0.38717
# [61]	validation_0-logloss:0.38523
# [62]	validation_0-logloss:0.38328
# [63]	validation_0-logloss:0.38129
# [64]	validation_0-logloss:0.37937
# [65]	validation_0-logloss:0.37747
# [66]	validation_0-logloss:0.37561
# [67]	validation_0-logloss:0.37369
# [68]	validation_0-logloss:0.37184
# [69]	validation_0-logloss:0.37011
# [70]	validation_0-logloss:0.36834
# [71]	validation_0-logloss:0.36655
# [72]	validation_0-logloss:0.36476
# [73]	validation_0-logloss:0.36298
# [74]	validation_0-logloss:0.36125
# [75]	validation_0-logloss:0.35956
# [76]	validation_0-logloss:0.35782
# [77]	validation_0-logloss:0.35610
# [78]	validation_0-logloss:0.35434
# [79]	validation_0-logloss:0.35267
# [80]	validation_0-logloss:0.35096
# [81]	validation_0-logloss:0.34930
# [82]	validation_0-logloss:0.34768
# [83]	validation_0-logloss:0.34605
# [84]	validation_0-logloss:0.34440
# [85]	validation_0-logloss:0.34284
# [86]	validation_0-logloss:0.34124
# [87]	validation_0-logloss:0.33967
# [88]	validation_0-logloss:0.33813
# [89]	validation_0-logloss:0.33661
# [90]	validation_0-logloss:0.33502
# [91]	validation_0-logloss:0.33346
# [92]	validation_0-logloss:0.33189
# [93]	validation_0-logloss:0.33038
# [94]	validation_0-logloss:0.32891
# [95]	validation_0-logloss:0.32743
# [96]	validation_0-logloss:0.32593
# [97]	validation_0-logloss:0.32441
# [98]	validation_0-logloss:0.32293
# [99]	validation_0-logloss:0.32145
# [100]	validation_0-logloss:0.31998
# [101]	validation_0-logloss:0.31855
# [102]	validation_0-logloss:0.31714
# [103]	validation_0-logloss:0.31572
# [104]	validation_0-logloss:0.31437
# [105]	validation_0-logloss:0.31294
# [106]	validation_0-logloss:0.31154
# [107]	validation_0-logloss:0.31018
# [108]	validation_0-logloss:0.30882
# [109]	validation_0-logloss:0.30741
# [110]	validation_0-logloss:0.30607
# [111]	validation_0-logloss:0.30480
# [112]	validation_0-logloss:0.30350
# [113]	validation_0-logloss:0.30213
# [114]	validation_0-logloss:0.30077
# [115]	validation_0-logloss:0.29948
# [116]	validation_0-logloss:0.29817
# [117]	validation_0-logloss:0.29691
# [118]	validation_0-logloss:0.29568
# [119]	validation_0-logloss:0.29447
# [120]	validation_0-logloss:0.29321
# [121]	validation_0-logloss:0.29198
# [122]	validation_0-logloss:0.29073
# [123]	validation_0-logloss:0.28950
# [124]	validation_0-logloss:0.28824
# [125]	validation_0-logloss:0.28697
# [126]	validation_0-logloss:0.28578
# [127]	validation_0-logloss:0.28457
# [128]	validation_0-logloss:0.28336
# [129]	validation_0-logloss:0.28214
# [130]	validation_0-logloss:0.28093
# [131]	validation_0-logloss:0.27973
# [132]	validation_0-logloss:0.27861
# [133]	validation_0-logloss:0.27745
# [134]	validation_0-logloss:0.27633
# [135]	validation_0-logloss:0.27513
# [136]	validation_0-logloss:0.27402
# [137]	validation_0-logloss:0.27290
# [138]	validation_0-logloss:0.27176
# [139]	validation_0-logloss:0.27069
# [140]	validation_0-logloss:0.26957
# [141]	validation_0-logloss:0.26846
# [142]	validation_0-logloss:0.26734
# [143]	validation_0-logloss:0.26625
# [144]	validation_0-logloss:0.26518
# [145]	validation_0-logloss:0.26409
# [146]	validation_0-logloss:0.26301
# [147]	validation_0-logloss:0.26193
# [148]	validation_0-logloss:0.26090
# [149]	validation_0-logloss:0.25985
# [150]	validation_0-logloss:0.25882
# [151]	validation_0-logloss:0.25774
# [152]	validation_0-logloss:0.25671
# [153]	validation_0-logloss:0.25570
# [154]	validation_0-logloss:0.25471
# [155]	validation_0-logloss:0.25362
# [156]	validation_0-logloss:0.25264
# [157]	validation_0-logloss:0.25167
# [158]	validation_0-logloss:0.25067
# [159]	validation_0-logloss:0.24965
# [160]	validation_0-logloss:0.24868
# [161]	validation_0-logloss:0.24768
# [162]	validation_0-logloss:0.24674
# [163]	validation_0-logloss:0.24577
# [164]	validation_0-logloss:0.24481
# [165]	validation_0-logloss:0.24391
# [166]	validation_0-logloss:0.24298
# [167]	validation_0-logloss:0.24206
# [168]	validation_0-logloss:0.24114
# [169]	validation_0-logloss:0.24023
# [170]	validation_0-logloss:0.23935
# [171]	validation_0-logloss:0.23840
# [172]	validation_0-logloss:0.23748
# [173]	validation_0-logloss:0.23658
# [174]	validation_0-logloss:0.23570
# [175]	validation_0-logloss:0.23478
# [176]	validation_0-logloss:0.23387
# [177]	validation_0-logloss:0.23300
# [178]	validation_0-logloss:0.23211
# [179]	validation_0-logloss:0.23120
# [180]	validation_0-logloss:0.23039
# [181]	validation_0-logloss:0.22953
# [182]	validation_0-logloss:0.22870
# [183]	validation_0-logloss:0.22784
# [184]	validation_0-logloss:0.22697
# [185]	validation_0-logloss:0.22605
# [186]	validation_0-logloss:0.22517
# [187]	validation_0-logloss:0.22435
# [188]	validation_0-logloss:0.22348
# [189]	validation_0-logloss:0.22264
# [190]	validation_0-logloss:0.22181
# [191]	validation_0-logloss:0.22098
# [192]	validation_0-logloss:0.22018
# [193]	validation_0-logloss:0.21937
# [194]	validation_0-logloss:0.21859
# [195]	validation_0-logloss:0.21777
# [196]	validation_0-logloss:0.21694
# [197]	validation_0-logloss:0.21608
# [198]	validation_0-logloss:0.21530
# [199]	validation_0-logloss:0.21453
# [200]	validation_0-logloss:0.21374
# [201]	validation_0-logloss:0.21294
# [202]	validation_0-logloss:0.21216
# [203]	validation_0-logloss:0.21142
# [204]	validation_0-logloss:0.21069
# [205]	validation_0-logloss:0.20988
# [206]	validation_0-logloss:0.20915
# [207]	validation_0-logloss:0.20833
# [208]	validation_0-logloss:0.20754
# [209]	validation_0-logloss:0.20677
# [210]	validation_0-logloss:0.20600
# [211]	validation_0-logloss:0.20525
# [212]	validation_0-logloss:0.20451
# [213]	validation_0-logloss:0.20377
# [214]	validation_0-logloss:0.20302
# [215]	validation_0-logloss:0.20230
# [216]	validation_0-logloss:0.20163
# [217]	validation_0-logloss:0.20087
# [218]	validation_0-logloss:0.20014
# [219]	validation_0-logloss:0.19938
# [220]	validation_0-logloss:0.19867
# [221]	validation_0-logloss:0.19796
# [222]	validation_0-logloss:0.19725
# [223]	validation_0-logloss:0.19658
# [224]	validation_0-logloss:0.19585
# [225]	validation_0-logloss:0.19512
# [226]	validation_0-logloss:0.19442
# [227]	validation_0-logloss:0.19374
# [228]	validation_0-logloss:0.19304
# [229]	validation_0-logloss:0.19232
# [230]	validation_0-logloss:0.19161
# [231]	validation_0-logloss:0.19095
# [232]	validation_0-logloss:0.19029
# [233]	validation_0-logloss:0.18959
# [234]	validation_0-logloss:0.18896
# [235]	validation_0-logloss:0.18830
# [236]	validation_0-logloss:0.18764
# [237]	validation_0-logloss:0.18698
# [238]	validation_0-logloss:0.18633
# [239]	validation_0-logloss:0.18565
# [240]	validation_0-logloss:0.18500
# [241]	validation_0-logloss:0.18435
# [242]	validation_0-logloss:0.18370
# [243]	validation_0-logloss:0.18307
# [244]	validation_0-logloss:0.18241
# [245]	validation_0-logloss:0.18179
# [246]	validation_0-logloss:0.18115
# [247]	validation_0-logloss:0.18054
# [248]	validation_0-logloss:0.17992
# [249]	validation_0-logloss:0.17928
# [250]	validation_0-logloss:0.17863
# [251]	validation_0-logloss:0.17799
# [252]	validation_0-logloss:0.17737
# [253]	validation_0-logloss:0.17676
# [254]	validation_0-logloss:0.17616
# [255]	validation_0-logloss:0.17551
# [256]	validation_0-logloss:0.17496
# [257]	validation_0-logloss:0.17433
# [258]	validation_0-logloss:0.17371
# [259]	validation_0-logloss:0.17314
# [260]	validation_0-logloss:0.17255
# [261]	validation_0-logloss:0.17198
# [262]	validation_0-logloss:0.17140
# [263]	validation_0-logloss:0.17081
# [264]	validation_0-logloss:0.17021
# [265]	validation_0-logloss:0.16964
# [266]	validation_0-logloss:0.16904
# [267]	validation_0-logloss:0.16849
# [268]	validation_0-logloss:0.16794
# [269]	validation_0-logloss:0.16740
# [270]	validation_0-logloss:0.16683
# [271]	validation_0-logloss:0.16628
# [272]	validation_0-logloss:0.16571
# [273]	validation_0-logloss:0.16517
# [274]	validation_0-logloss:0.16460
# [275]	validation_0-logloss:0.16404
# [276]	validation_0-logloss:0.16346
# [277]	validation_0-logloss:0.16295
# [278]	validation_0-logloss:0.16242
# [279]	validation_0-logloss:0.16187
# [280]	validation_0-logloss:0.16135
# [281]	validation_0-logloss:0.16080
# [282]	validation_0-logloss:0.16026
# [283]	validation_0-logloss:0.15974
# [284]	validation_0-logloss:0.15922
# [285]	validation_0-logloss:0.15872
# [286]	validation_0-logloss:0.15821
# [287]	validation_0-logloss:0.15766
# [288]	validation_0-logloss:0.15715
# [289]	validation_0-logloss:0.15658
# [290]	validation_0-logloss:0.15606
# [291]	validation_0-logloss:0.15556
# [292]	validation_0-logloss:0.15501
# [293]	validation_0-logloss:0.15446
# [294]	validation_0-logloss:0.15394
# [295]	validation_0-logloss:0.15344
# [296]	validation_0-logloss:0.15293
# [297]	validation_0-logloss:0.15243
# [298]	validation_0-logloss:0.15194
# [299]	validation_0-logloss:0.15141
# [300]	validation_0-logloss:0.15088
# [301]	validation_0-logloss:0.15036
# [302]	validation_0-logloss:0.14986
# [303]	validation_0-logloss:0.14936
# [304]	validation_0-logloss:0.14884
# [305]	validation_0-logloss:0.14836
# [306]	validation_0-logloss:0.14788
# [307]	validation_0-logloss:0.14736
# [308]	validation_0-logloss:0.14688
# [309]	validation_0-logloss:0.14641
# [310]	validation_0-logloss:0.14595
# [311]	validation_0-logloss:0.14544
# [312]	validation_0-logloss:0.14494
# [313]	validation_0-logloss:0.14450
# [314]	validation_0-logloss:0.14406
# [315]	validation_0-logloss:0.14355
# [316]	validation_0-logloss:0.14310
# [317]	validation_0-logloss:0.14262
# [318]	validation_0-logloss:0.14216
# [319]	validation_0-logloss:0.14169
# [320]	validation_0-logloss:0.14125
# [321]	validation_0-logloss:0.14080
# [322]	validation_0-logloss:0.14031
# [323]	validation_0-logloss:0.13985
# [324]	validation_0-logloss:0.13943
# [325]	validation_0-logloss:0.13900
# [326]	validation_0-logloss:0.13855
# [327]	validation_0-logloss:0.13809
# [328]	validation_0-logloss:0.13765
# [329]	validation_0-logloss:0.13725
# [330]	validation_0-logloss:0.13682
# [331]	validation_0-logloss:0.13639
# [332]	validation_0-logloss:0.13598
# [333]	validation_0-logloss:0.13556
# [334]	validation_0-logloss:0.13514
# [335]	validation_0-logloss:0.13471
# [336]	validation_0-logloss:0.13427
# [337]	validation_0-logloss:0.13386
# [338]	validation_0-logloss:0.13342
# [339]	validation_0-logloss:0.13300
# [340]	validation_0-logloss:0.13262
# [341]	validation_0-logloss:0.13221
# [342]	validation_0-logloss:0.13180
# [343]	validation_0-logloss:0.13136
# [344]	validation_0-logloss:0.13096
# [345]	validation_0-logloss:0.13055
# [346]	validation_0-logloss:0.13013
# [347]	validation_0-logloss:0.12972
# [348]	validation_0-logloss:0.12931
# [349]	validation_0-logloss:0.12892
# [350]	validation_0-logloss:0.12851
# [351]	validation_0-logloss:0.12808
# [352]	validation_0-logloss:0.12765
# [353]	validation_0-logloss:0.12725
# [354]	validation_0-logloss:0.12684
# [355]	validation_0-logloss:0.12643
# [356]	validation_0-logloss:0.12605
# [357]	validation_0-logloss:0.12566
# [358]	validation_0-logloss:0.12523
# [359]	validation_0-logloss:0.12484
# [360]	validation_0-logloss:0.12446
# [361]	validation_0-logloss:0.12407
# [362]	validation_0-logloss:0.12369
# [363]	validation_0-logloss:0.12331
# [364]	validation_0-logloss:0.12293
# [365]	validation_0-logloss:0.12256
# [366]	validation_0-logloss:0.12218
# [367]	validation_0-logloss:0.12179
# [368]	validation_0-logloss:0.12140
# [369]	validation_0-logloss:0.12101
# [370]	validation_0-logloss:0.12063
# [371]	validation_0-logloss:0.12026
# [372]	validation_0-logloss:0.11988
# [373]	validation_0-logloss:0.11953
# [374]	validation_0-logloss:0.11918
# [375]	validation_0-logloss:0.11882
# [376]	validation_0-logloss:0.11848
# [377]	validation_0-logloss:0.11811
# [378]	validation_0-logloss:0.11775
# [379]	validation_0-logloss:0.11739
# [380]	validation_0-logloss:0.11701
# [381]	validation_0-logloss:0.11664
# [382]	validation_0-logloss:0.11629
# [383]	validation_0-logloss:0.11595
# [384]	validation_0-logloss:0.11556
# [385]	validation_0-logloss:0.11519
# [386]	validation_0-logloss:0.11487
# [387]	validation_0-logloss:0.11454
# [388]	validation_0-logloss:0.11420
# [389]	validation_0-logloss:0.11389
# [390]	validation_0-logloss:0.11353
# [391]	validation_0-logloss:0.11319
# [392]	validation_0-logloss:0.11284
# [393]	validation_0-logloss:0.11250
# [394]	validation_0-logloss:0.11216
# [395]	validation_0-logloss:0.11184
# [396]	validation_0-logloss:0.11150
# [397]	validation_0-logloss:0.11116
# [398]	validation_0-logloss:0.11080
# [399]	validation_0-logloss:0.11048
# [400]	validation_0-logloss:0.11016
# [401]	validation_0-logloss:0.10984
# [402]	validation_0-logloss:0.10952
# [403]	validation_0-logloss:0.10921
# [404]	validation_0-logloss:0.10888
# [405]	validation_0-logloss:0.10854
# [406]	validation_0-logloss:0.10822
# [407]	validation_0-logloss:0.10792
# [408]	validation_0-logloss:0.10757
# [409]	validation_0-logloss:0.10729
# [410]	validation_0-logloss:0.10699
# [411]	validation_0-logloss:0.10664
# [412]	validation_0-logloss:0.10633
# [413]	validation_0-logloss:0.10603
# [414]	validation_0-logloss:0.10570
# [415]	validation_0-logloss:0.10540
# [416]	validation_0-logloss:0.10511
# [417]	validation_0-logloss:0.10480
# [418]	validation_0-logloss:0.10451
# [419]	validation_0-logloss:0.10422
# [420]	validation_0-logloss:0.10390
# [421]	validation_0-logloss:0.10360
# [422]	validation_0-logloss:0.10332
# [423]	validation_0-logloss:0.10299
# [424]	validation_0-logloss:0.10268
# [425]	validation_0-logloss:0.10239
# [426]	validation_0-logloss:0.10211
# [427]	validation_0-logloss:0.10181
# [428]	validation_0-logloss:0.10150
# [429]	validation_0-logloss:0.10124
# [430]	validation_0-logloss:0.10099
# [431]	validation_0-logloss:0.10070
# [432]	validation_0-logloss:0.10041
# [433]	validation_0-logloss:0.10010
# [434]	validation_0-logloss:0.09982
# [435]	validation_0-logloss:0.09953
# [436]	validation_0-logloss:0.09925
# [437]	validation_0-logloss:0.09899
# [438]	validation_0-logloss:0.09872
# [439]	validation_0-logloss:0.09847
# [440]	validation_0-logloss:0.09820
# [441]	validation_0-logloss:0.09792
# [442]	validation_0-logloss:0.09765
# [443]	validation_0-logloss:0.09737
# [444]	validation_0-logloss:0.09710
# [445]	validation_0-logloss:0.09681
# [446]	validation_0-logloss:0.09653
# [447]	validation_0-logloss:0.09623
# [448]	validation_0-logloss:0.09593
# [449]	validation_0-logloss:0.09564
# [450]	validation_0-logloss:0.09539
# [451]	validation_0-logloss:0.09513
# [452]	validation_0-logloss:0.09488
# [453]	validation_0-logloss:0.09462
# [454]	validation_0-logloss:0.09434
# [455]	validation_0-logloss:0.09410
# [456]	validation_0-logloss:0.09385
# [457]	validation_0-logloss:0.09360
# [458]	validation_0-logloss:0.09335
# [459]	validation_0-logloss:0.09307
# [460]	validation_0-logloss:0.09280
# [461]	validation_0-logloss:0.09257
# [462]	validation_0-logloss:0.09230
# [463]	validation_0-logloss:0.09208
# [464]	validation_0-logloss:0.09180
# [465]	validation_0-logloss:0.09152
# [466]	validation_0-logloss:0.09128
# [467]	validation_0-logloss:0.09101
# [468]	validation_0-logloss:0.09075
# [469]	validation_0-logloss:0.09050
# [470]	validation_0-logloss:0.09026
# [471]	validation_0-logloss:0.09001
# [472]	validation_0-logloss:0.08976
# [473]	validation_0-logloss:0.08948
# [474]	validation_0-logloss:0.08920
# [475]	validation_0-logloss:0.08893
# [476]	validation_0-logloss:0.08866
# [477]	validation_0-logloss:0.08841
# [478]	validation_0-logloss:0.08818
# [479]	validation_0-logloss:0.08795
# [480]	validation_0-logloss:0.08771
# [481]	validation_0-logloss:0.08749
# [482]	validation_0-logloss:0.08725
# [483]	validation_0-logloss:0.08699
# [484]	validation_0-logloss:0.08676
# [485]	validation_0-logloss:0.08654
# [486]	validation_0-logloss:0.08631
# [487]	validation_0-logloss:0.08606
# [488]	validation_0-logloss:0.08583
# [489]	validation_0-logloss:0.08556
# [490]	validation_0-logloss:0.08531
# [491]	validation_0-logloss:0.08505
# [492]	validation_0-logloss:0.08484
# [493]	validation_0-logloss:0.08460
# [494]	validation_0-logloss:0.08437
# [495]	validation_0-logloss:0.08415
# [496]	validation_0-logloss:0.08391
# [497]	validation_0-logloss:0.08368
# [498]	validation_0-logloss:0.08344
# [499]	validation_0-logloss:0.08321
# Spectrogram Model Accuracy (with regularization): 0.9871
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      3904
#            1       0.98      1.00      0.99     11816
#
#     accuracy                           0.99     15720
#    macro avg       0.99      0.97      0.98     15720
# weighted avg       0.99      0.99      0.99     15720

# %%
import joblib  # Ensure joblib is imported

joblib.dump(model_spectrogram, '/kaggle/working/XGBOSST.pkl')
# Out:
# ['/kaggle/working/XGBOSST.pkl']
